# %% [markdown]
# ### TPC6: Análise de dados: doença cardíaca
#
# Descarregue o ficheiro de dados: [diabetes_prediction_dataset.csv](./datasets/diabetes_prediction_dataset.csv.zip).
#
# Encontra mais informação sobre este conjunto de dados [aqui](https://www.kaggle.com/datasets/iammustafatz/diabetes-prediction-dataset).
#
# Crie um programa em Python, conjunto de funções, que responda às seguintes questões:
# * Crie uma função que lê a informação do ficheiro para um modelo, previamente pensado em memória;
# * Crie uma função que calcula a distribuição da doença por sexo (tenha atenção que indivíduos doentes e não doentes no dataset);
# * Crie uma função que calcula a distribuição da doença por escalões etários. Considere os seguintes escalões: [0-10], [11-24], [25-29], [30-34], [35-39], [40-44], ...
# * Crie uma função que calcula a distribuição da doença por níveis de glucose. Considere um nível igual a um intervalo de 10 unidades, comece no limite inferior e crie os níveis necessários até abranger o limite superior;
# * Crie uma função que imprime na forma de uma tabela uma distribuição;
# * Especifique um programa que ao executar apresenta as tabelas correspondentes às distribuições pedidas.

# %%
import csv

tabela = []

def lerinformacao():
    ficheiro = open('diabetes_prediction_dataset.csv', mode='r')
    ficheiro.readline() #Apaga a primeira linha
    inftabela = csv.reader(ficheiro, delimiter=',')
    for linha in inftabela:
        tabela.append((linha[0],float(linha[1]),int(linha[2]),int(linha[3]),linha[4],float(linha[5]),float(linha[6]),int(linha[7]),int(linha[8])))
    print(tabela)

def distribuicaosexo():
    lerinformacao()
    contadorM = 0
    contadorF = 0
    for t in tabela:
        gender,age,hypertension,heart_disease,smoking_history,bmi,HbA1c_level,blood_glucose_level,diabetes = t
        if diabetes == 1 and gender == "M":
            contadorM += 1
        elif diabetes == 1 and gender == "F":
            contadorF += 1
    print("Contagem Masculina:", contadorM)
    print("Contagem Feminina:", contadorF)

def distribuicaoidade():
    lerinformacao()
    escaloes = [[0, 10], [11, 24], [25, 29], [30,39], [40, 44], [45, 49], [50, 54], [55, 59], [60, 64], [65, 69], [70, 74], [75, 79], [80, 84], [85, 89]]
    lista = []
    for t in tabela:
        gender,age,hypertension,heart_disease,smoking_history,bmi,HbA1c_level,blood_glucose_level,diabetes = t
        for escalao in escaloes:
            if diabetes == 1 and age >= escalao[0] and age <= escalao[1]:
                lista.append(escalao)
    for escalao in escaloes:
        print("Escalão", escalao, "tem:", lista.count(escalao), "pessoas")

def distribuicaocolestrol():
    lerinformacao()
    lista=[]
    nivelglucose=[[0,10],[100,110],[110,120],[120,130],[130,140],[140,150],[150,160],[160,170],[170,180],[180,190],[190,200],[200,210],[210,220],[220,230],[230,240],[240,250],[250,260],[260,270],[270,280],[280,290],[290,300],[300,310],[310,320],[320,330],[330,340],[340,350]]
    for t in tabela:
        gender,age,hypertension,heart_disease,smoking_history,bmi,HbA1c_level,blood_glucose_level,diabetes = t
        for nivel in nivelglucose:
            if diabetes == 1 and blood_glucose_level >= nivel[0] and blood_glucose_level <= nivel[1]:
                lista.append(nivel)
    for nivel in nivelglucose:
            print("Nivel", nivel, "tem:", lista.count(nivel), "pessoas")

def menu():
    opcao= int(input("intoduza o número entre 1 e 4:"))
    if opcao == 1:
        lerinformacao()
    elif opcao == 2:
        distribuicaosexo()
    elif opcao == 3:
        distribuicaoidade()
    elif opcao == 4:
        distribuicaocolestrol()
menu()
